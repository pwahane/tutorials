# %% [markdown]
# # Visualisations
#
# ## Matplotlib and Seaborn
#
# * Matplotlib is a 2D plotting python library for python
# * Seaborn is built on top of matplotlib

# %%
! pip install matplotlib
! pip install seaborn
# Out:
# zsh:1: command not found: pip
# zsh:1: command not found: pip

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# #### Plot a point

# %%
plt.plot(4,3,'.')

# %% [markdown]
# #### Plot a number of points

# %%
x = np.array([2,4,6,8,10,12,14,16])
y = x/2

plt.figure(figsize=(10,5))
plt.scatter(x,y,c='magenta')

# %% [markdown]
# #### Label the axis

# %%
plt.plot([1,2,3,4])
plt.ylabel('y-axis')
plt.xlabel('x-axis')
# Out:
# Text(0.5, 0, 'x-axis')

# %% [markdown]
# #### Create multiple plots with subplots

# %%
classes = ['John','Sanjay','Ellen','Sandra','Nancy','Shubham','Philip']
scores = [10,15,20,30,40,50,100]
plt.figure(figsize=(20,5))
plt.subplot(131) # 1st row having 3 columns and 1st column
plt.bar(classes,scores)
plt.subplot(132) # 1st row having 3 columns and 2nd column
plt.scatter(classes,scores)
plt.subplot(133) # 1st row having 3 columns and 3rd column
plt.plot(classes,scores)
plt.suptitle('Categorical Plotting')
# Out:
# Text(0.5, 0.98, 'Categorical Plotting')

# %% [markdown]
# #### Correlations type

# %% [markdown]
# ![correlations](images/correlations.png)

# %%
auto_data = pd.read_csv('data/Automobile.csv')
auto_data
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %% [markdown]
# ## Seaborn
# #### Plot correlation between two variables in dataframe

# %%
sns.lmplot(x='horsepower',y='price',data=auto_data)

# %% [markdown]
# #### Remove the regression line

# %%
sns.lmplot(x='horsepower',y='price',data=auto_data,fit_reg=False)

# %% [markdown]
# #### Adding a 3D space into 2D (Using hue)

# %%
sns.lmplot(x='horsepower',y='price',data=auto_data,fit_reg=True,hue="body_style")

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# #### Plot Distribution (Histogram)

# %%
sns.displot(auto_data['highway_mpg'],kde=True)

# %% [markdown]
# #### Remove kernal density

# %%
sns.displot(auto_data['highway_mpg'],kde=False)

# %% [markdown]
# #### Distribution Types
#
# ![Distribution](images/distribution.png)

# %% [markdown]
# #### Plot only kernal density

# %%
sns.kdeplot(auto_data['highway_mpg'],shade=True)
# Out:
# <AxesSubplot:xlabel='highway_mpg', ylabel='Density'>

# %%
sns.boxplot(data=auto_data['price'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# #### Joint Plot

# %%
sns.jointplot(x=auto_data['horsepower'],y=auto_data['price'])

# %% [markdown]
# #### Confirm the correlation

# %%
auto_data[['horsepower','price']].corr()
# Out:
#             horsepower     price
# horsepower    1.000000  0.810795
# price         0.810795  1.000000

# %%
sns.jointplot(x=auto_data['horsepower'],y=auto_data['price'],kind='kde')

# %%
sns.jointplot(x=auto_data['horsepower'],y=auto_data['price'],kind='reg')

# %% [markdown]
# #### Pair plot (Used for more than two variables)

# %%
sns.pairplot(auto_data[['horsepower','price','highway_mpg']],kind='scatter')

# %%
sns.pairplot(auto_data[['horsepower','price','highway_mpg']],kind='scatter',diag_kind='kde')

# %%
sns.stripplot(x=auto_data['number_of_doors'],y=auto_data['horsepower'])
# Out:
# <AxesSubplot:xlabel='number_of_doors', ylabel='horsepower'>

# %%
sns.boxplot(x=auto_data['number_of_doors'],y=auto_data['horsepower'])
# Out:
# <AxesSubplot:xlabel='number_of_doors', ylabel='horsepower'>

# %%
sns.barplot(x=auto_data['number_of_doors'],y=auto_data['horsepower'])
# Out:
# <AxesSubplot:xlabel='number_of_doors', ylabel='horsepower'>

# %%
sns.countplot(x=auto_data['fuel_type'])
# Out:
# <AxesSubplot:xlabel='fuel_type', ylabel='count'>
